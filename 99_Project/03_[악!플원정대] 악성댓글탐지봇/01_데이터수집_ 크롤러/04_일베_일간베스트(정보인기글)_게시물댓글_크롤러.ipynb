# %% [markdown]
# ###### 2020-11-12 목요일

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from tqdm import tqdm_notebook

import time
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. "일간베스트" 사이트접속

# %%
path='./chrome_Driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get("https://www.ilbe.com/list/ilbe?sub=best")

time.sleep(5)

# %% [markdown]
# ## 2. "일간베스트" 사이트의 일간베스트 게시물 최근 5개 Page 게시물에 대하여 크롤링 진행

# %%
# 페이지 지정 : 최근 5개 페이지 크롤링
input_page = [1, 123, 224, 363 ]


# 전체댓글을 담을 리스트
post_comment = []

for page_num in tqdm_notebook(input_page) :
    url = "https://www.ilbe.com/list/ilbe?page=" + str(page_num) + "&sub=best&listStyle=list"
    
    driver.get(url)
        
    ilbe_bestpost_body_list = driver.find_elements_by_css_selector('#content-wrap > div.board-wrap > div.board-list > ul.board-body > li')

    n = len(ilbe_bestpost_body_list)


    k=1

    for idx in tqdm_notebook(range(5, n)) :

        print(k, '번째 게시물입니다')
        k += 1

        # 게시물을 차례대로 눌러 페이지를 변환
        post = ilbe_bestpost_body_list[idx]
        post_click = post.find_element_by_css_selector('span.title > a')
        post_click.click()

        time.sleep(5)

        # 게시물의 댓글 리스트를 넘겨준다
        page = driver.find_elements_by_css_selector('div.post-comment-wrap > div.comment-group > div.paginate > a')
        page_change = page[2 : (len(page)-2) ]

        m = len(page_change)


        # 댓글 페이지가 하나인 경우 같은 페이지를 맴돌며 크롤링한 댓글을 다시 크롤링하는 현상이발생
        # 나중에 pd.unique를 사용하여 동일한 열을 제거하자
        for idx2 in range(m):
            print(idx2 + 1, '페이지')
            num_btn = page_change[idx2]
            try:
                num_btn.click()
            except:
                print('댓글 페이지가 하나입니다.')
            time.sleep(1)


            comment_list = driver.find_elements_by_css_selector('#content-wrap > div.board-wrap > div.board-view > div.post-comment-wrap > div.comment-group > div.comment-item')
            l = len(comment_list)

            # 댓글 크롤링!
            for idx3 in range(l):
                comment = comment_list[idx3]

                try :
                    comment_text = comment.find_element_by_css_selector('div.comment-item-box > div.comment > span.comment-box').text
                    post_comment.append(comment_text)

                except :
                    print('삭제된 댓글 입니다.')

                comment_list = driver.find_elements_by_css_selector('#content-wrap > div.board-wrap > div.board-view > div.post-comment-wrap > div.comment-group > div.comment-item')


            page = driver.find_elements_by_css_selector('div.post-comment-wrap > div.comment-group > div.paginate > a')
            page_change = page[2 : (len(page)-2)]


        # 게시물을 담은 바디리스트 초기화되기 때문에 재지정
        driver.back()

        time.sleep(2)
        ilbe_bestpost_body_list = driver.find_elements_by_css_selector('#content-wrap > div.board-wrap > div.board-list > ul.board-body > li')
        time.sleep(3)

        
        print('현재까지의 댓글수 :', len(post_comment))
        print('')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))
# 1 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
#
# 2 번째 게시물입니다
# 1 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 3 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 4 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
#
# 5 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 6 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 3 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 4 페이지
# 삭제된 댓글 입니다.
#
# 7 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 3 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 8 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
#
# 9 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 삭제된 댓글 입니다.
# 4 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
#
# 10 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
#
# 11 번째 게시물입니다
# 1 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
#
# 12 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 13 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 14 번째 게시물입니다
# 1 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 15 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 16 번째 게시물입니다
# 1 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 17 번째 게시물입니다
# 1 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 18 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 3 페이지
# 삭제된 댓글 입니다.
# 4 페이지
# 삭제된 댓글 입니다.
# 5 페이지
# 삭제된 댓글 입니다.
# 6 페이지
# 삭제된 댓글 입니다.
#
# 19 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
#
# 20 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
#
# 21 번째 게시물입니다
# 1 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 4 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 5 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 22 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 3 페이지
# 삭제된 댓글 입니다.
# 4 페이지
# 삭제된 댓글 입니다.
#
# 23 번째 게시물입니다
# 1 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 4 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 5 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
#
# 24 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 3 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 4 페이지
# 삭제된 댓글 입니다.
# 5 페이지
# 삭제된 댓글 입니다.
#
# 25 번째 게시물입니다
# 1 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 4 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 5 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 6 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
#
# 26 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
#
# 27 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
#
# 28 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 삭제된 댓글 입니다.
# 4 페이지
# 삭제된 댓글 입니다.
#
# 29 번째 게시물입니다
# 1 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 4 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
#
# 30 번째 게시물입니다
# 1 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))
# 1 번째 게시물입니다
# 1 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 3 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 4 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
# 5 페이지
# 댓글 페이지가 하나입니다.
# 삭제된 댓글 입니다.
#
# 2 번째 게시물입니다
#
# 3 번째 게시물입니다
# 1 페이지
# 삭제된 댓글 입니다.
# 삭제된 댓글 입니다.
# 2 페이지
# 삭제된 댓글 입니다.
#
# 4 번째 게시물입니다
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-196-fa18cbcba0ae> in <module>
#      28
#      29         # 게시물의 댓글 리스트를 넘겨준다
# ---> 30         page = driver.find_elements_by_css_selector('div.post-comment-wrap > div.comment-group > div.paginate > a')
#      31         page_change = page[2 : (len(page)-2) ]
#      32
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_css_selector(self, css_selector)
#     612             elements = driver.find_elements_by_css_selector('.foo')
#     613         """
# --> 614         return self.find_elements(by=By.CSS_SELECTOR, value=css_selector)
#     615
#     616     def execute_script(self, script, *args):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1005         return self.execute(Command.FIND_ELEMENTS, {
#    1006             'using': by,
# -> 1007             'value': value})['value'] or []
#    1008
#    1009     @property
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=86.0.4240.198)

# %%
unique_list = pd.unique(post_comment)

print(len(unique_list))

df = pd.DataFrame({'댓글' : unique_list})

df.to_csv('./크롤링한 댓글 데이터/일베_일간베스트게시물_댓글.csv', encoding='utf-8-sig')
# Out:
# 67
