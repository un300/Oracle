# %% [markdown]
# ###### 2020-11-06 금요일
# ###### 2020-11-07 토요일

# %% [markdown]
# # 01_Tensorflow2.0_(1)

# %% [markdown]
#    - tensorflow2.0을 가지고 간단한 실습을 진행해보자
#    - 딥러닝은 자연어처리, 영상처리에 많이 사용되기 때문에 자연어 처리를 하려면 잘 해놓자

# %% [markdown]
# ### 목차
#
# #### 1. 데이터정제
#
# #### 2. Train / Test 분할
#
# #### 3. 정규화
#
# #### 4. 딥러닝

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ##### 다음 데이터 셋으로 딥러링을 학습시켜 연비(mpg)를 예측해보자
# - Auto MPG Dataset

# %%
dataset_path = keras.utils.get_file("auto-mpg.data", "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
dataset_path
# Out:
# 'C:\\Users\\lan41\\.keras\\datasets\\auto-mpg.data'

# %%
raw_dataset = pd.read_csv(dataset_path, header=None, sep='\s+')
columns = ['mpg' , 'cylinders' , 'displacement' , 'horsepower', 'weight' , 'acceleration', 'model year', 'origin' , 'name']
raw_dataset.columns = columns

# %%
raw_dataset.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
copy_df = raw_dataset.copy()

# %%
copy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# ## 1. 데이터정제

# %% [markdown]
# ##### `horsepower`

# %%
# 데이터정제
# horsepower칼럼에 `?` 가존재
copy_df['horsepower'].unique()
# Out:
# array(['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0',
#        '225.0', '190.0', '170.0', '160.0', '95.00', '97.00', '85.00',
#        '88.00', '46.00', '87.00', '90.00', '113.0', '200.0', '210.0',
#        '193.0', '?', '100.0', '105.0', '175.0', '153.0', '180.0', '110.0',
#        '72.00', '86.00', '70.00', '76.00', '65.00', '69.00', '60.00',
#        '80.00', '54.00', '208.0', '155.0', '112.0', '92.00', '145.0',
#        '137.0', '158.0', '167.0', '94.00', '107.0', '230.0', '49.00',
#        '75.00', '91.00', '122.0', '67.00', '83.00', '78.00', '52.00',
#        '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#        '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0',
#        '108.0', '68.00', '58.00', '149.0', '89.00', '63.00', '48.00',
#        '66.00', '139.0', '103.0', '125.0', '133.0', '138.0', '135.0',
#        '142.0', '77.00', '62.00', '132.0', '84.00', '64.00', '74.00',
#        '116.0', '82.00'], dtype=object)

# %%
copy_df['horsepower'] = copy_df['horsepower'].replace('?', np.NaN).apply(float)

# %%
copy_df.isna().apply(sum)
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# name            0
# dtype: int64

# %%
copy_df = copy_df.dropna(subset=['horsepower'], axis=0, inplace=False)

# %%
copy_df.shape
# Out:
# (392, 9)

# %% [markdown]
# ##### `origin`

# %% [markdown]
#  - 숫자형으로 되어있기 때문에

# %%
copy_df['origin'] = copy_df['origin'].astype(str)

# %%
copy_df.pop('name')
copy_df = pd.get_dummies(copy_df)

# %%
copy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    int64
#  7   origin_1      392 non-null    uint8
#  8   origin_2      392 non-null    uint8
#  9   origin_3      392 non-null    uint8
# dtypes: float64(5), int64(2), uint8(3)
# memory usage: 25.6 KB

# %% [markdown]
# ## 2. Train / Test 분할
#    - tensorflow와 sklearn의 함수를 같이 쓰는 경우는 본적이 없다.
#    - 그래서 tensorlow를 이용해 딥러닝을 사용하면서 sklearn의 train_test_split을 사용하지 않는편이 좋다
#    - 그러므로 sklearn을 이용해 train / test를 나누는 것이 아니라, pandas의 sample 함수를 이용하여 train / test를 나눈다

# %%
train_set = copy_df.sample(frac=0.8, random_state=0)
test_set = copy_df.drop(train_set.index)

# %%
y_train = train_set.pop('mpg')
y_test  = test_set.pop('mpg')
X_train = train_set
X_test  = test_set

# %%
sns.pairplot(train_set[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight']], diag_kind='kde')

# %% [markdown]
# ## 3. 정규화
#    - 딥러닝은 Feature를 딥러닝에 넣어 학습시키기 전에 정규화 과정이 필요하다
#    - 왜냐??
#        - 딥러닝은 비용함수(에러)를 작게하는 지점을 찾기위해 **경사하강법**을 사용하는데 정규화하지 않은 데이터의 경우 비용함수(에러)를 작게하는 지점을 찾기가 정규화를 한 경우보다 어렵다. 그러므로 수행속도가 더욱 오래 걸리기에 정규화를 하는 것이 필수라 할 수 있다.

# %%
train_stats= X_train.describe().T

print(train_stats['mean'])
print(train_stats['std'])
# Out:
# cylinders          5.477707
# displacement     195.318471
# horsepower       104.869427
# weight          2990.251592
# acceleration      15.559236
# model year        75.898089
# origin_1           0.624204
# origin_2           0.178344
# origin_3           0.197452
# Name: mean, dtype: float64
# cylinders         1.699788
# displacement    104.331589
# horsepower       38.096214
# weight          843.898596
# acceleration      2.789230
# model year        3.675642
# origin_1          0.485101
# origin_2          0.383413
# origin_3          0.398712
# Name: std, dtype: float64

# %% [markdown]
# ###### 데이터 정규화
#    - 정규화는 Train set의 평균 분산을 사용하여 Train set과 Test set의 정규화를 진행하여야한다.
#    - sklearn에서 정규화를 위해 `StandardScaler()`함수를 사용할때도 설명했지만, 다시설명 하자면..
#        - 머신러닝과 딥러닝은 Train set으로만 학습시켜야한다.
#        - 그렇기 때문에 Train set + Test set의 평균 분산을 사용하여 정규화를 진행한다면, 어떤 형식으로든 Test set의 정보가 포함되어 머신러닝 또는 딥러닝을 학습시키는 것과 같다.
#        - 그렇다고, Train set의 평균 분산을 사용하여 Train set을 정규화하고, Test set의 평균 분산을 사용하여 Test set을 정규화해서도 안된다.
#        - 정석적인 방법은 Train set의 평균 분산을 이용해 Train set과 Test set을 정규화하여야 한다.

# %%
# 데이터 정규화

def norm(train, test):
    train_stats = train.describe().T
    
    norm_train = (train - train_stats['mean']) / train_stats['std']
    norm_test  = (test - train_stats['mean']) / train_stats['std']
    
    return norm_train, norm_test

# %%
X_train_norm, X_test_norm = norm(X_train, X_test)

# %% [markdown]
# ## 4. 딥러닝

# %% [markdown]
# ##### 딥러닝 모델 구현하기

# %% [markdown]
#    - 1. `Sequential`로 모델을 만들자
#        - 우리의 경우 입력층(노드64), 히든층(노드64), 출력층(노드1)으로 총 3층으로 이룬 모델을 구축할 것이다.
#    - 2. `optimizers` : 딥러닝 모델의 학습 방식을 지정해 주는것이다. 자세한 방법은 구글링을 해주길 바란다.
#    - 3. `compile` : 딥러닝의 학습방식과 주요 성능지표로 삼을 오차를 지정해준다.

# %%
# 모델 만들기


# 딥러닝 계츨 구조 구축
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[len(train_set.keys())]),   # 은닉층
    layers.Dense(64, activation='relu'),   #
    layers.Dense(1)  # 출력층
])

optimizer = tf.keras.optimizers.RMSprop()

model.compile(loss      = 'mse',
              optimizer = optimizer,  # 딥러닝 학습방식을 설정해주 
              metrics   = ['mae', 'mse'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 64)                640
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Train set을 이용하여 딥러닝 학습하기

# %% [markdown]
#  - `.fit()`을 이용하여 딥러닝을 학습시키자

# %%
leaning_history = model.fit(X_train_norm, y_train,
                            epochs           = 200,  # 딥러닝을 200번 학습시킨다
                            validation_split = 0.2,   # train과 valdation을 8:2로 나눈다
                            verbose          = 1) # 딥러닝 학습과정을 출력한다
# Out:
# Train on 251 samples, validate on 63 samples
# Epoch 1/200
# 251/251 [==============================] - 0s 834us/sample - loss: 409.8833 - mae: 18.8904 - mse: 409.8833 - val_loss: 375.7532 - val_mae: 17.9686 - val_mse: 375.7532
# Epoch 2/200
# 251/251 [==============================] - 0s 194us/sample - loss: 345.6094 - mae: 17.2048 - mse: 345.6093 - val_loss: 304.1279 - val_mae: 15.9886 - val_mse: 304.1279
# Epoch 3/200
# 251/251 [==============================] - 0s 193us/sample - loss: 279.4465 - mae: 15.3127 - mse: 279.4465 - val_loss: 232.9413 - val_mae: 13.7552 - val_mse: 232.9413
# Epoch 4/200
# 251/251 [==============================] - 0s 190us/sample - loss: 215.2164 - mae: 13.2319 - mse: 215.2164 - val_loss: 169.3727 - val_mae: 11.4328 - val_mse: 169.3727
# Epoch 5/200
# 251/251 [==============================] - 0s 175us/sample - loss: 158.2562 - mae: 11.0644 - mse: 158.2562 - val_loss: 116.8477 - val_mae: 9.2829 - val_mse: 116.8477
# Epoch 6/200
# 251/251 [==============================] - 0s 203us/sample - loss: 110.4935 - mae: 8.9303 - mse: 110.4935 - val_loss: 77.5527 - val_mae: 7.5056 - val_mse: 77.5527
# Epoch 117/200
# 251/251 [==============================] - 0s 175us/sample - loss: 6.0315 - mae: 1.6913 - mse: 6.0315 - val_loss: 9.0959 - val_mae: 2.2001 - val_mse: 9.0959
# Epoch 118/200
# 251/251 [==============================] - 0s 135us/sample - loss: 5.9493 - mae: 1.7394 - mse: 5.9493 - val_loss: 8.7281 - val_mae: 2.2754 - val_mse: 8.7281
# Epoch 119/200
# 251/251 [==============================] - 0s 163us/sample - loss: 5.9628 - mae: 1.7120 - mse: 5.9628 - val_loss: 9.0060 - val_mae: 2.2800 - val_mse: 9.0060
# Epoch 120/200
# 251/251 [==============================] - 0s 234us/sample - loss: 6.0298 - mae: 1.7162 - mse: 6.0298 - val_loss: 9.4012 - val_mae: 2.2213 - val_mse: 9.4012
# Epoch 121/200
# 251/251 [==============================] - 0s 226us/sample - loss: 5.9811 - mae: 1.7477 - mse: 5.9811 - val_loss: 8.7215 - val_mae: 2.2609 - val_mse: 8.7215
# Epoch 122/200
# 251/251 [==============================] - 0s 234us/sample - loss: 6.1964 - mae: 1.7472 - mse: 6.1964 - val_loss: 8.8494 - val_mae: 2.2708 - val_mse: 8.8494
# Epoch 123/200
# 251/251 [==============================] - 0s 231us/sample - loss: 5.9898 - mae: 1.6740 - mse: 5.9898 - val_loss: 8.7147 - val_mae: 2.2286 - val_mse: 8.7147
# Epoch 124/200
# 251/251 [==============================] - 0s 163us/sample - loss: 5.8835 - mae: 1.7268 - mse: 5.8835 - val_loss: 8.7973 - val_mae: 2.3459 - val_mse: 8.7973
# Epoch 125/200
# 251/251 [==============================] - 0s 167us/sample - loss: 5.8840 - mae: 1.6718 - mse: 5.8840 - val_loss: 8.7803 - val_mae: 2.2785 - val_mse: 8.7803
# Epoch 126/200
# 251/251 [==============================] - 0s 206us/sample - loss: 5.9583 - mae: 1.7078 - mse: 5.9583 - val_loss: 8.9886 - val_mae: 2.2261 - val_mse: 8.9886
# Epoch 127/200
# 251/251 [==============================] - 0s 167us/sample - loss: 5.9749 - mae: 1.7129 - mse: 5.9749 - val_loss: 8.9370 - val_mae: 2.2975 - val_mse: 8.9370
# Epoch 128/200
# 251/251 [==============================] - 0s 183us/sample - loss: 5.9120 - mae: 1.7112 - mse: 5.9120 - val_loss: 8.9931 - val_mae: 2.1969 - val_mse: 8.9931
# Epoch 129/200
# 251/251 [==============================] - 0s 190us/sample - loss: 5.9759 - mae: 1.7233 - mse: 5.9759 - val_loss: 8.8648 - val_mae: 2.3220 - val_mse: 8.8648
# Epoch 130/200
# 251/251 [==============================] - 0s 179us/sample - loss: 5.9461 - mae: 1.7031 - mse: 5.9461 - val_loss: 8.7046 - val_mae: 2.2437 - val_mse: 8.7046
# Epoch 131/200
# 251/251 [==============================] - 0s 183us/sample - loss: 5.6896 - mae: 1.6472 - mse: 5.6896 - val_loss: 9.1380 - val_mae: 2.1864 - val_mse: 9.1380
# Epoch 132/200
# 251/251 [==============================] - 0s 151us/sample - loss: 5.8567 - mae: 1.7009 - mse: 5.8567 - val_loss: 8.5404 - val_mae: 2.2679 - val_mse: 8.5404
# Epoch 133/200
# 251/251 [==============================] - 0s 135us/sample - loss: 6.0741 - mae: 1.7026 - mse: 6.0741 - val_loss: 8.6933 - val_mae: 2.2872 - val_mse: 8.6933
# Epoch 134/200
# 251/251 [==============================] - 0s 171us/sample - loss: 5.7994 - mae: 1.6734 - mse: 5.7994 - val_loss: 8.8226 - val_mae: 2.1848 - val_mse: 8.8226
# Epoch 135/200
# 251/251 [==============================] - 0s 151us/sample - loss: 5.9355 - mae: 1.7234 - mse: 5.9355 - val_loss: 8.7162 - val_mae: 2.2396 - val_mse: 8.7162
# Epoch 136/200
# 251/251 [==============================] - 0s 131us/sample - loss: 5.7975 - mae: 1.7076 - mse: 5.7975 - val_loss: 8.7895 - val_mae: 2.2161 - val_mse: 8.7895
# Epoch 137/200
# 251/251 [==============================] - 0s 143us/sample - loss: 5.9187 - mae: 1.7083 - mse: 5.9187 - val_loss: 8.6331 - val_mae: 2.2425 - val_mse: 8.6331
# Epoch 138/200
# 251/251 [==============================] - 0s 159us/sample - loss: 5.7819 - mae: 1.6849 - mse: 5.7819 - val_loss: 8.7380 - val_mae: 2.1981 - val_mse: 8.7380
# Epoch 139/200
# 251/251 [==============================] - 0s 187us/sample - loss: 6.0231 - mae: 1.7283 - mse: 6.0231 - val_loss: 8.5641 - val_mae: 2.2222 - val_mse: 8.5641
# Epoch 140/200
# 251/251 [==============================] - 0s 175us/sample - loss: 5.7632 - mae: 1.6958 - mse: 5.7632 - val_loss: 8.7722 - val_mae: 2.3479 - val_mse: 8.7722
# Epoch 141/200
# 251/251 [==============================] - 0s 158us/sample - loss: 5.8759 - mae: 1.6809 - mse: 5.8759 - val_loss: 8.5182 - val_mae: 2.2445 - val_mse: 8.5182
# Epoch 142/200
# 251/251 [==============================] - 0s 167us/sample - loss: 5.7276 - mae: 1.6798 - mse: 5.7276 - val_loss: 9.0499 - val_mae: 2.3546 - val_mse: 9.0499
# Epoch 143/200
# 251/251 [==============================] - 0s 187us/sample - loss: 5.8023 - mae: 1.6647 - mse: 5.8023 - val_loss: 9.2527 - val_mae: 2.2113 - val_mse: 9.2527
# Epoch 144/200
# 251/251 [==============================] - 0s 163us/sample - loss: 5.7779 - mae: 1.7085 - mse: 5.7779 - val_loss: 8.7301 - val_mae: 2.2398 - val_mse: 8.7301
# Epoch 145/200
# 251/251 [==============================] - 0s 155us/sample - loss: 5.7335 - mae: 1.6855 - mse: 5.7335 - val_loss: 8.6544 - val_mae: 2.2409 - val_mse: 8.6544
# Epoch 146/200
# 251/251 [==============================] - 0s 179us/sample - loss: 5.6361 - mae: 1.6442 - mse: 5.6361 - val_loss: 9.3417 - val_mae: 2.4438 - val_mse: 9.3417
# Epoch 147/200
# 251/251 [==============================] - 0s 167us/sample - loss: 5.7004 - mae: 1.6753 - mse: 5.7004 - val_loss: 9.2824 - val_mae: 2.2052 - val_mse: 9.2824
# Epoch 148/200
# 251/251 [==============================] - 0s 179us/sample - loss: 5.7007 - mae: 1.6877 - mse: 5.7007 - val_loss: 8.8260 - val_mae: 2.3705 - val_mse: 8.8260
# Epoch 149/200
# 251/251 [==============================] - 0s 183us/sample - loss: 5.7805 - mae: 1.6877 - mse: 5.7805 - val_loss: 8.8730 - val_mae: 2.2181 - val_mse: 8.8730
# Epoch 150/200
# 251/251 [==============================] - 0s 179us/sample - loss: 5.7102 - mae: 1.6488 - mse: 5.7102 - val_loss: 8.7498 - val_mae: 2.2425 - val_mse: 8.7498
# Epoch 151/200
# 251/251 [==============================] - 0s 175us/sample - loss: 5.8597 - mae: 1.6952 - mse: 5.8597 - val_loss: 8.9716 - val_mae: 2.3589 - val_mse: 8.9716
# Epoch 152/200
# 251/251 [==============================] - 0s 171us/sample - loss: 5.6837 - mae: 1.6491 - mse: 5.6837 - val_loss: 8.8914 - val_mae: 2.2171 - val_mse: 8.8914
# Epoch 153/200
# 251/251 [==============================] - 0s 178us/sample - loss: 5.7834 - mae: 1.6658 - mse: 5.7834 - val_loss: 9.1927 - val_mae: 2.2748 - val_mse: 9.1927
# Epoch 154/200
# 251/251 [==============================] - 0s 167us/sample - loss: 5.6031 - mae: 1.6693 - mse: 5.6031 - val_loss: 8.6751 - val_mae: 2.2725 - val_mse: 8.6751
# Epoch 155/200
# 251/251 [==============================] - 0s 200us/sample - loss: 5.7428 - mae: 1.6628 - mse: 5.7428 - val_loss: 8.6265 - val_mae: 2.3151 - val_mse: 8.6265
# Epoch 156/200
# 251/251 [==============================] - 0s 183us/sample - loss: 5.7527 - mae: 1.6687 - mse: 5.7527 - val_loss: 8.6686 - val_mae: 2.2675 - val_mse: 8.6686
# Epoch 157/200
# 251/251 [==============================] - 0s 167us/sample - loss: 5.7525 - mae: 1.6656 - mse: 5.7525 - val_loss: 8.6484 - val_mae: 2.2502 - val_mse: 8.6484
# Epoch 158/200
# 251/251 [==============================] - 0s 159us/sample - loss: 5.6580 - mae: 1.6811 - mse: 5.6580 - val_loss: 8.7667 - val_mae: 2.2893 - val_mse: 8.7667
# Epoch 159/200
# 251/251 [==============================] - 0s 278us/sample - loss: 5.5554 - mae: 1.6364 - mse: 5.5554 - val_loss: 8.6570 - val_mae: 2.2272 - val_mse: 8.6570
# Epoch 160/200
# 251/251 [==============================] - 0s 350us/sample - loss: 5.6489 - mae: 1.6604 - mse: 5.6489 - val_loss: 8.7479 - val_mae: 2.2239 - val_mse: 8.7479
# Epoch 161/200
# 251/251 [==============================] - 0s 314us/sample - loss: 5.7203 - mae: 1.6714 - mse: 5.7203 - val_loss: 8.7956 - val_mae: 2.3327 - val_mse: 8.7956
# Epoch 162/200
# 251/251 [==============================] - 0s 381us/sample - loss: 5.5982 - mae: 1.6430 - mse: 5.5982 - val_loss: 8.6438 - val_mae: 2.2967 - val_mse: 8.6438
# Epoch 163/200
# 251/251 [==============================] - 0s 369us/sample - loss: 5.6443 - mae: 1.6760 - mse: 5.6443 - val_loss: 8.6812 - val_mae: 2.2227 - val_mse: 8.6812
# Epoch 164/200
# 251/251 [==============================] - 0s 358us/sample - loss: 5.6881 - mae: 1.6795 - mse: 5.6881 - val_loss: 8.5724 - val_mae: 2.2240 - val_mse: 8.5724
# Epoch 165/200
# 251/251 [==============================] - 0s 385us/sample - loss: 5.8090 - mae: 1.6759 - mse: 5.8090 - val_loss: 8.6148 - val_mae: 2.2554 - val_mse: 8.6148
# Epoch 166/200
# 251/251 [==============================] - 0s 322us/sample - loss: 5.6877 - mae: 1.6491 - mse: 5.6877 - val_loss: 8.5165 - val_mae: 2.2596 - val_mse: 8.5165
# Epoch 167/200
# 251/251 [==============================] - 0s 155us/sample - loss: 5.6474 - mae: 1.6312 - mse: 5.6474 - val_loss: 9.0028 - val_mae: 2.1893 - val_mse: 9.0028
# Epoch 168/200
# 251/251 [==============================] - 0s 191us/sample - loss: 5.6656 - mae: 1.6477 - mse: 5.6656 - val_loss: 8.6227 - val_mae: 2.1959 - val_mse: 8.6227
# Epoch 169/200
# 251/251 [==============================] - 0s 198us/sample - loss: 5.5370 - mae: 1.6556 - mse: 5.5370 - val_loss: 8.9143 - val_mae: 2.3268 - val_mse: 8.9143
# Epoch 170/200
# 251/251 [==============================] - 0s 175us/sample - loss: 5.6828 - mae: 1.6626 - mse: 5.6828 - val_loss: 8.8247 - val_mae: 2.3482 - val_mse: 8.8247
# Epoch 171/200
# 251/251 [==============================] - 0s 179us/sample - loss: 5.5881 - mae: 1.6528 - mse: 5.5881 - val_loss: 9.1680 - val_mae: 2.2214 - val_mse: 9.1680
# Epoch 172/200
# 251/251 [==============================] - 0s 191us/sample - loss: 5.5626 - mae: 1.6503 - mse: 5.5626 - val_loss: 8.9026 - val_mae: 2.3775 - val_mse: 8.9026
# Epoch 173/200
# 251/251 [==============================] - 0s 163us/sample - loss: 5.5708 - mae: 1.6734 - mse: 5.5708 - val_loss: 8.4788 - val_mae: 2.2758 - val_mse: 8.4788
# Epoch 174/200
# 251/251 [==============================] - 0s 187us/sample - loss: 5.6490 - mae: 1.6375 - mse: 5.6490 - val_loss: 8.7504 - val_mae: 2.2348 - val_mse: 8.7504
# Epoch 175/200
# 251/251 [==============================] - 0s 231us/sample - loss: 5.5343 - mae: 1.6335 - mse: 5.5343 - val_loss: 8.7938 - val_mae: 2.3172 - val_mse: 8.7938
# Epoch 176/200
# 251/251 [==============================] - 0s 250us/sample - loss: 5.5042 - mae: 1.6348 - mse: 5.5042 - val_loss: 9.0604 - val_mae: 2.4040 - val_mse: 9.0604
# Epoch 177/200
# 251/251 [==============================] - 0s 254us/sample - loss: 5.6457 - mae: 1.6160 - mse: 5.6457 - val_loss: 8.6473 - val_mae: 2.2233 - val_mse: 8.6473
# Epoch 178/200
# 251/251 [==============================] - 0s 254us/sample - loss: 5.6701 - mae: 1.6524 - mse: 5.6701 - val_loss: 8.6968 - val_mae: 2.2937 - val_mse: 8.6968
# Epoch 179/200
# 251/251 [==============================] - 0s 222us/sample - loss: 5.4615 - mae: 1.6017 - mse: 5.4615 - val_loss: 8.6784 - val_mae: 2.2396 - val_mse: 8.6784
# Epoch 180/200
# 251/251 [==============================] - 0s 222us/sample - loss: 5.4791 - mae: 1.6082 - mse: 5.4791 - val_loss: 8.3976 - val_mae: 2.2498 - val_mse: 8.3976
# Epoch 181/200
# 251/251 [==============================] - 0s 249us/sample - loss: 5.4864 - mae: 1.6411 - mse: 5.4864 - val_loss: 8.4766 - val_mae: 2.2582 - val_mse: 8.4766
# Epoch 182/200
# 251/251 [==============================] - 0s 239us/sample - loss: 5.3638 - mae: 1.6031 - mse: 5.3638 - val_loss: 8.4256 - val_mae: 2.2469 - val_mse: 8.4256
# Epoch 183/200
# 251/251 [==============================] - 0s 262us/sample - loss: 5.3911 - mae: 1.6358 - mse: 5.3911 - val_loss: 9.0145 - val_mae: 2.1987 - val_mse: 9.0145
# Epoch 184/200
# 251/251 [==============================] - 0s 234us/sample - loss: 5.5630 - mae: 1.6662 - mse: 5.5630 - val_loss: 8.5261 - val_mae: 2.2740 - val_mse: 8.5261
# Epoch 185/200
# 251/251 [==============================] - 0s 262us/sample - loss: 5.6225 - mae: 1.6439 - mse: 5.6225 - val_loss: 8.6582 - val_mae: 2.2901 - val_mse: 8.6582
# Epoch 186/200
# 251/251 [==============================] - 0s 183us/sample - loss: 5.4155 - mae: 1.6203 - mse: 5.4155 - val_loss: 8.6629 - val_mae: 2.2125 - val_mse: 8.6629
# Epoch 187/200
# 251/251 [==============================] - 0s 131us/sample - loss: 5.7155 - mae: 1.6707 - mse: 5.7155 - val_loss: 9.0175 - val_mae: 2.3710 - val_mse: 9.0175
# Epoch 188/200
# 251/251 [==============================] - ETA: 0s - loss: 9.1395 - mae: 1.7510 - mse: 9.139 - 0s 139us/sample - loss: 5.5034 - mae: 1.5885 - mse: 5.5034 - val_loss: 8.5000 - val_mae: 2.2202 - val_mse: 8.5000
# Epoch 189/200
# 251/251 [==============================] - 0s 123us/sample - loss: 5.4866 - mae: 1.6132 - mse: 5.4866 - val_loss: 8.4188 - val_mae: 2.2173 - val_mse: 8.4188
# Epoch 190/200
# 251/251 [==============================] - 0s 127us/sample - loss: 5.4824 - mae: 1.6153 - mse: 5.4824 - val_loss: 8.9880 - val_mae: 2.2258 - val_mse: 8.9880
# Epoch 191/200
# 251/251 [==============================] - 0s 136us/sample - loss: 5.7334 - mae: 1.6641 - mse: 5.7334 - val_loss: 8.5702 - val_mae: 2.2179 - val_mse: 8.5702
# Epoch 192/200
# 251/251 [==============================] - 0s 167us/sample - loss: 5.3382 - mae: 1.5951 - mse: 5.3382 - val_loss: 8.8899 - val_mae: 2.1849 - val_mse: 8.8899
# Epoch 193/200
# 251/251 [==============================] - 0s 191us/sample - loss: 5.4110 - mae: 1.6196 - mse: 5.4110 - val_loss: 8.7741 - val_mae: 2.2226 - val_mse: 8.7741
# Epoch 194/200
# 251/251 [==============================] - 0s 164us/sample - loss: 5.3752 - mae: 1.6192 - mse: 5.3752 - val_loss: 8.6267 - val_mae: 2.2350 - val_mse: 8.6267
# Epoch 195/200
# 251/251 [==============================] - 0s 230us/sample - loss: 5.5327 - mae: 1.6457 - mse: 5.5327 - val_loss: 8.5886 - val_mae: 2.2492 - val_mse: 8.5886
# Epoch 196/200
# 251/251 [==============================] - 0s 346us/sample - loss: 5.5562 - mae: 1.6581 - mse: 5.5562 - val_loss: 8.5451 - val_mae: 2.2740 - val_mse: 8.5451
# Epoch 197/200
# 251/251 [==============================] - 0s 377us/sample - loss: 5.4319 - mae: 1.5962 - mse: 5.4319 - val_loss: 8.5154 - val_mae: 2.2220 - val_mse: 8.5154
# Epoch 198/200
# 251/251 [==============================] - 0s 362us/sample - loss: 5.3840 - mae: 1.5916 - mse: 5.3840 - val_loss: 8.7677 - val_mae: 2.2166 - val_mse: 8.7677
# Epoch 199/200
# 251/251 [==============================] - 0s 358us/sample - loss: 5.4745 - mae: 1.6076 - mse: 5.4745 - val_loss: 8.5393 - val_mae: 2.2410 - val_mse: 8.5393
# Epoch 200/200
# 251/251 [==============================] - 0s 350us/sample - loss: 5.6445 - mae: 1.6430 - mse: 5.6445 - val_loss: 8.6709 - val_mae: 2.2403 - val_mse: 8.6709

# %%
# 딥러닝의 학습 과정을 데이터프레임으로 만들었다.
hist_df = pd.DataFrame(leaning_history.history)
hist_df.tail(10)
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse
# 190  5.733416  1.664068  5.733417  8.570188  2.217899  8.570189
# 191  5.338218  1.595082  5.338217  8.889924  2.184872  8.889924
# 192  5.411013  1.619579  5.411013  8.774103  2.222605  8.774102
# 193  5.375184  1.619222  5.375185  8.626695  2.235049  8.626696
# 194  5.532695  1.645707  5.532695  8.588626  2.249172  8.588625
# 195  5.556183  1.658062  5.556182  8.545146  2.273958  8.545147
# 196  5.431943  1.596236  5.431942  8.515410  2.221956  8.515409
# 197  5.384018  1.591550  5.384017  8.767680  2.216648  8.767679
# 198  5.474462  1.607604  5.474462  8.539281  2.240962  8.539282
# 199  5.644505  1.643015  5.644505  8.670918  2.240265  8.670918

# %% [markdown]
# ##### Test set을 이용하여 예측하고 모델의 성능을 평가해보자

# %% [markdown]
#  - `evaluate()`함수를 이용하면 Test set에 대한 예측값과 실제값의 차이(오차)를 알아서 계산해준다.

# %%
loss, mae, mse = model.evaluate(X_test_norm, y_test)
print('평균 절대 오차 :', mae)
# Out:
# 78/78 [==============================] - 0s 128us/sample - loss: 8.9142 - mae: 2.1373 - mse: 8.9142
# 평균 절대 오차 : 2.1372955

# %% [markdown]
# - 하지만, 예측값 그자체가 필요하다면 머신러닝의 predict와 같은 방법으로 예측을 수행하면 된다

# %%
y_pred = model.predict(X_test_norm)

# %% [markdown]
# ###### 실제값와 예측값의 차이를 시각화 하여 차이점을 한눈에 알아보자

# %%
# 시각화
y_pred = model.predict(X_test_norm).flatten()

# %%
df = pd.DataFrame({
    'pred' : y_pred,
    'real' : np.array(y_test)
})
df.head()
# Out:
#         pred  real
# 0  16.313959  15.0
# 1  10.547772  10.0
# 2  11.355962   9.0
# 3  24.196756  25.0
# 4  20.965286  19.0

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>
