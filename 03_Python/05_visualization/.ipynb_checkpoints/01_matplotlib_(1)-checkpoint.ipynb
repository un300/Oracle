# %% [markdown]
# ###### 2020-10-19 월요일
# ###### 2020-10-20 화요일

# %% [markdown]
# # Python 시각화 (1)
#
#  - 시각화 패키지 : matplotlib (pyplot)  /  seaborn
#  - 분석된 내용을 시각화하는 수업
#  - Pandas 내부의 시각화

# %% [markdown]
# ### 목차
# ### 1. Plot
# ### 2. Line 겹처 그리기
# ### 3. 그래프 여러개 그리기
# ### 4. 플롯의 유형
# ### 5. iris dataset을 이용한 시각화 연습
# ### 6. car_mpg.xls [실습]
# ### 7. 이상치정제

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# 한글폰트 깨짐
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12
plt.rcParams['figure.figsize'] = (14, 4)

# 마이너스 깨짐
mpl.rcParams['axes.unicode_minus'] = False

# %%
# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# ## 1.plot
#    - 데이터가 시간, 순서 등에 따라 어떻게 변화하는지를 보여주는 그래프

# %%
plt.title('line plot')
plt.plot([1, 4, 9, 16])
plt.show()

# %%
plt.title('line plot')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %% [markdown]
#  ##### 약어를 이용하여 Plot을 그릴 수 있다.
#  - option(color, marker, style)
#  - color : b , r
#  - marker : o
#  - style : -- , - , :
#
#
#
#  ###### 아래의 이미지를 참조하라

# %%
from IPython.display import Image

Image('./line_style.PNG')

# %%
plt.title('line plot')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'bs--')
plt.show()

# %%
plt.title('라인 플롯')
plt.plot( [10, 20, 30 ,40], [1, 4, 9, 10],
        c = 'b',
        lw = 5, ls='--', marker='o', ms=40, mec='g', mew=5, mfc='r')
plt.xlabel('x 라벨')
plt.ylabel('y 라벨')
# Out:
# Text(0, 0.5, 'y 라벨')

# %%
plt.title('라인 플롯')
plt.plot( [10, 20, 30 ,40], [1, 4, 9, 10],
        c = 'b',
        lw = 5, ls='--', marker='o', ms=40, mec='g', mew=5, mfc='r')
plt.xlabel('x 라벨')
plt.ylabel('y 라벨')
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
Y = np.cos(X)
plt.plot(X, Y)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, 1])
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
Y = np.cos(X)
plt.plot(X, Y)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, 1])
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. line 겹처 그리기
#    - plt.plot()을 중첩하여 그래프(라인)을 겹처서 그릴 수 있다.

# %%
data = np.arange(0., 5.0, 0.2)
data
plt.title('여러개의 라인 플롯')
plt.plot(data, data, 'r--')
plt.plot(data, data**2, 'b--')
plt.plot(data, data**3, 'g--')
plt.plot(data, data**4, 'y--')
plt.show()

# %%
plt.title('라인 겹쳐 그리기')

plt.plot( [1, 4, 9, 10],
        c = 'b',
        lw = 5, ls='--', marker='o', ms=40, mec='g', mew=5, mfc='r')

plt.plot( [9, 14, 5, 20],
        c = 'g',
        lw = 3, ls='--', marker='s', ms=20, mec='y', mew=3, mfc='b')
plt.legend(loc=1)

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
X = np.linspace(-np.pi, np.pi, 256)
Y_C, Y_S = np.cos(X), np.sin(X)

plt.plot(X, Y_C, ls='--', label='cos')
plt.plot(X, Y_S, ls='--', label='sin')
plt.legend(loc=0) ## loc는 0 ~ 10까지 부여해서 자리를 지정할 수 있는데,
                  ## 0으로주면 라인과 겹처지지 않는 최적의 자리에 범주를 배정시킴
plt.show()

# %% [markdown]
# ## 3. 그래프 여러개 그리기

# %% [markdown]
#  ##### matplotlib 그림을 그리는 객체, fiigure, axes, axis 객체를 포함하고 있다.
#  - figure : 그림이 그려지는 종이를 뜻함
#  - Axes : 플롯
#  - Axis : 축

# %%
np.random.seed(100)
plt.figure(figsize=(10, 2))
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# ##### 하나의 화면에 여러가지 그래프를 그릴때
#
#  - subplot(2, 1, 1) : 2행 1열에 첫번째 그래프
#  - subplot(2, 1, 2) : 2행 1열에 두번째 그래프

# %%
# 그래프를 두개 그리기위해 의미없는 데이터를 만들어 줌

X1 = np.linspace(0.0, 5.0)
Y1 = np.cos(2 * np.pi * X1) * np.exp(-X1)
print(X1)
print(Y1)

X2 = np.linspace(0.0, 2.0)
Y2 = np.cos(2 * np.pi * X2)
print(X2)
print(Y2)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]
# [ 1.          0.72367065  0.2320026  -0.25429107 -0.55721991 -0.59913951
#  -0.41280458 -0.10893327  0.17893551  0.34780448  0.35748852  0.23380958
#   0.04690762 -0.12275601 -0.21591812 -0.21241248 -0.13137462 -0.01694367
#   0.08259904  0.1333648   0.12567347  0.0731473   0.00339549 -0.05472957
#  -0.08198104 -0.07402828 -0.04029719  0.00203856  0.03580865  0.05016511
# ...

# %%
# subplot을 그리는 방법1

axes01 = plt.subplot(1, 2, 1)
plt.plot(X1, Y1, 'rs--')
plt.title('subplot_01')

axes02 = plt.subplot(1, 2, 2)
plt.plot(X2, Y2, 'go-')
plt.title('subplot_02')

plt.tight_layout()  ## subplot간의 간격을 자동으로 맞추어 주는 함수
plt.show()

# %%
# subplot을 그리는 방법2 : 객체의 형태로 subplot을 그리는 방법

axes01 = plt.subplot(1, 2, 1)
axes02 = plt.subplot(1, 2, 2)


axes01.plot(X1, Y1, 'rs--')
axes01.set_title('subplot01')   # set_title()함수 plt.title()의 차이점을 알아라


axes02.plot(X2, Y2, 'go--')
axes02.set_title('subplot02')

plt.tight_layout() 
plt.show()

# %% [markdown]
# ## 4. 플롯의 유형
#  - line plot
#  - scatter plot
#  - contour plot
#  - surface plot
#  - bar plot
#  - histogram plot
#  - box plot
#
#
#
#
#
#  ##### 몇가지 그래프만 그려보자

# %% [markdown]
# ##### (1) Bar plot

# %%
Y = [2, 3, 1]
X = np.arange(len(Y))


plot1 = plt.subplot(1, 2, 1)
plot2 = plt.subplot(1, 2, 2)

xlabel = ['1등석', '2등석', '3등석']

plot1.set_title('수직')
plot1.bar(X, Y)
plot1.set_xticks(X, xlabel)
plot1.set_yticks(sorted(Y))
plot1.set_xlabel('선실 등급')
plot1.set_ylabel('생존자 수')


plot2.set_title('수평')
plot2.barh(X, Y)
plot2.set_xticks(X, xlabel)
plot2.set_yticks(sorted(Y))
plot2.set_xlabel('선실 등급')
plot2.set_ylabel('생존자 수')


# subplot에서 조건으 넣을떈,
# [subplot객체].set_[함수]
# 이 형태로 적어주어야 하내!
# Out:
# Text(0, 0.5, '생존자 수')

# %% [markdown]
# ## 5. iris dataset을 이용한 시각화 연습
# ##### 데이터프레임에 바로 plot 적용하여 그래프 그리기

# %%
import seaborn as sns
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris['species'].value_counts()
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
# 칼럼이름 변경
iris = iris.rename(columns = {iris.columns[0] : 'SL',
                              iris.columns[1] : 'SW',
                              iris.columns[2] : 'PL',
                              iris.columns[3] : 'PW',
                              iris.columns[4] : 'Y'})

# %%
iris[['SL', 'SW']].loc[:5]
# Out:
#     SL   SW
# 0  5.1  3.5
# 1  4.9  3.0
# 2  4.7  3.2
# 3  4.6  3.1
# 4  5.0  3.6
# 5  5.4  3.9

# %% [markdown]
# ##### Pandas 복습
#    - 종을 기준으로 그룹화하여 각 그룹의 평균을 구해본다면?

# %%
species_mean = iris.groupby(iris.Y).agg(np.mean)
species_mean.columns.name = 'SP'
species_mean.T
# Out:
# Y   setosa  versicolor  virginica
# SP
# SL   5.006       5.936      6.588
# SW   3.428       2.770      2.974
# PL   1.462       4.260      5.552
# PW   0.246       1.326      2.026

# %% [markdown]
# ##### 데이터프레임 : 바로 Plot그리기
#    - Bar를 나누는 기준은 행을 먼저 따르고 다음으로 열을 따른다.
#    - 이해가 안되면 밑의 코드를 참조하자

# %% [markdown]
#    행인 `SL`, `SW`, `PL`, `PW`를 기준으로 Bar를 나누고,
#    열인 `setosa', versicolor`, `virginica`를 기준으로 내부 Bar를 나눈다.

# %%
display(species_mean.T)
species_mean.T.plot.bar(rot=0)
# Out:
# Y   setosa  versicolor  virginica
# SP
# SL   5.006       5.936      6.588
# SW   3.428       2.770      2.974
# PL   1.462       4.260      5.552
# PW   0.246       1.326      2.026

# %% [markdown]
#    반대로도 해보자
#    이해되지유?

# %%
display(species_mean)
species_mean.plot.bar()
# Out:
# SP             SL     SW     PL     PW
# Y
# setosa      5.006  3.428  1.462  0.246
# versicolor  5.936  2.770  4.260  1.326
# virginica   6.588  2.974  5.552  2.026

# %% [markdown]
#  - iris boxplot

# %%
iris[['SL', 'Y']].head()
# Out:
#     SL       Y
# 0  5.1  setosa
# 1  4.9  setosa
# 2  4.7  setosa
# 3  4.6  setosa
# 4  5.0  setosa

# %%
iris[['SL', 'Y']].boxplot(by='Y')
plt.title('종에 따른 SL의 boxplot')
plt.xlabel('type')
plt.ylabel('cm')
plt.tight_layout(pad=3) # pad : 그래프와 title간 사이 간격
plt.show()

# %% [markdown]
# ##### 하나의 화면에 여러가지 그래프를 그리는 방법
#    - `plt.subplots()`

# %%
fig, axes = plt.subplots(2, 2)

iris.columns

iris[ [iris.columns[0], 'Y'] ].boxplot(by='Y', ax=axes[0, 0])
iris[ [iris.columns[1], 'Y'] ].boxplot(by='Y', ax=axes[0, 1])
iris[ [iris.columns[2], 'Y'] ].boxplot(by='Y', ax=axes[1, 0])
iris[ [iris.columns[3], 'Y'] ].boxplot(by='Y', ax=axes[1, 1])

# %%
iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Y'], dtype='object')

# %% [markdown]
# ## 6. car_mpg.xls [실습]

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ##### `car_mpg.xlsx` 데이터를 이용해서 실습해보자

# %%
data_df = pd.read_excel('./실습데이터/car_mpg.xlsx')
del data_df['Unnamed: 0']

# %%
data_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %% [markdown]
#  - 양적자료 : 요약 정보에 집계가 되는 컬럼으로 관측된 값이 수치 형태의 속성을 가지는 자료이다. 쉽게말해 수치형 자료
#  - 질적자료 : 범주 또는 순서 형태의 속성을 가지는 자료로서 도수 분포표와 히스토그램으로 데이터의 분포를 확인해야 하는 자료형이다. 쉽게말해 수치가 아닌 자료

# %%
# 양적자료의 데이터 분포 확인
data_df[ ['displ', 'cyl', 'cty', 'hwy'] ].plot.box()
plt.title('양적자료 시각화')
plt.grid(True)

# %%
# 질적자료의 데이터 빈도 확인 : 제조회사의 데이터 빈도
data_df.groupby(data_df['manufacturer']).size().plot.bar()

# 모델명의 데이터빈도
data_df['model'].value_counts().plot.bar()

# %%
# 질적자료의 데이터 빈도 확인 : 모델명의 데이터빈도
data_df['model'].value_counts().plot.bar()

# %%
# 질적자료의 데이터 빈도 확인 : 클래스의 데이터빈도
data_df['class'].value_counts().plot.bar()

# %% [markdown]
# ## 실습

# %% [markdown]
# ##### 문제01]
#    - 자동차 배기량(displ)에 따라 고속도로연비(hwy)가 다른지 알아보자
#    - 배기량이 4이하인 자동차와 5이상인 자동차 중 어떤 자동차의 고속도로연비가 평균적으로 더 높은가?

# %%
f1 = lambda x : '4이하' if x <=4 else '4초과 5미만'
f2 = lambda y : '5이상' if y >=5 else f1(y)

data_df[ 'displ_class' ] = data_df[ 'displ' ].apply(f2)
data_df[ ['displ_class', 'hwy'] ].groupby('displ_class').agg(np.mean).plot.bar()

# %% [markdown]
# ##### 문제 02]
#    - 자동차 제조 회사에 따라 도시 연비가 다른지 알아보려고 한다.
#    - audi와 toyota 중 어느 manufacturer(자동차 제조회사)의 cty(도시연비)가 평균적으로 더 높은지 알아보시오

# %%
index_audi = data_df['manufacturer'] == 'audi'
index_toyota = data_df['manufacturer'] == 'toyota'

want_df = data_df[ index_audi | index_toyota ] 
want_df[ ['manufacturer', 'hwy'] ].groupby('manufacturer').agg(np.mean).plot.barh()

## audi의 cty(도시연비)가 더 높다

# %% [markdown]
# ##### 문제03]
#    - chevorlet, ford, honda 자동차의 고속도로연비(hwy) 평균을 알아보려고 한다.
#    - 이 회사들의 데이터를 추출한 후 hwy 전체 평균을 확인하라

# %%
chevrolet_index   = data_df['manufacturer'] == 'chevrolet'
ford_index        = data_df['manufacturer'] == 'ford'
honda_index       = data_df['manufacturer'] == 'honda'

temp_df = data_df.loc[chevrolet_index | ford_index | honda_index, :]
mean_df = temp_df[ ['manufacturer', 'hwy'] ].groupby(temp_df.manufacturer).agg(np.mean)
mean_df.plot.bar()

display(mean_df)
print('세 자동차 회사의 hwy의 평균 : ', temp_df['hwy'].mean())
# Out:
#                     hwy
# manufacturer
# chevrolet     21.894737
# ford          19.360000
# honda         32.555556
# 세 자동차 회사의 hwy의 평균 :  22.50943396226415

# %% [markdown]
# ##### 문제03]을 query를 이용하여 구하세요

# %%
manufacturer_list = ['chevrolet', 'ford', 'honda']
data_df.query('manufacturer in @manufacturer_list')['hwy'].mean()
# Out:
# 22.50943396226415

# %% [markdown]
#  - 데이터 전처리 : 연료가격 변수 추가
#      - c : 가스
#      - d : 디젤
#      - e : 에탄올
#      - p : 고급휘발유
#      - r : 보통휘발유

# %% [markdown]
# ##### 복습 : 데이터프레임끼리 병합해 보세요 (pd.merge)

# %%
fl_df = pd.DataFrame({
    'fl'       : ['c', 'd', 'e', 'p', 'r'],
    'price_fl' : [2.35, 2.38, 2.11, 2.76, 2.22]
})
fl_df

hap_che_df = pd.merge(data_df, fl_df, on='fl', how='left')
display(hap_che_df)

# pd,merge한 데이터프레임에서 model, fl, price_fl만 추출
hap_che_df[['model', 'fl', 'price_fl']]
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class displ_class  price_fl
# 0    compact         4이하      2.76
# ...

# %% [markdown]
# ##### 문제04]
#    - hwy 변수의 결측값을 제외하고, 어떤 구동방식의 고속도로평균 연비가 높은지 알아보자.

# %%
# 랜덤으로 hwy에 결측값 넣기
np.random.seed(123)
random_index = np.random.randint(0, hap_che_df.shape[0], 20)
hap_che_df.loc[random_index, ['hwy'] ] = np.NaN

# 구동방식(drv)에 따라 평균치 구하기
drop_na_df = hap_che_df.dropna()
drop_na_df.info()

# 구동방식별 연비평균을 비교하기 위해 막대그래프로 시각화
for_plot_df = drop_na_df.groupby('drv').mean()[['hwy']]

display(for_plot_df)
for_plot_df.plot.bar(rot=0)
plt.title('구동방식별 평균연비')
plt.xlabel('구동방식')
plt.ylabel('연비')
plt.grid(True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 215 entries, 0 to 233
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  215 non-null    object
#  1   model         215 non-null    object
#  2   displ         215 non-null    float64
#  3   year          215 non-null    int64
#  4   cyl           215 non-null    int64
#  5   trans         215 non-null    object
#  6   drv           215 non-null    object
#  7   cty           215 non-null    int64
#  8   hwy           215 non-null    float64
#  9   fl            215 non-null    object
#  10  class         215 non-null    object
#  11  displ_class   215 non-null    object
#  12  price_fl      215 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 23.5+ KB
#            hwy
# drv
# 4    19.315789
# f    28.237113
# r    20.956522

# %% [markdown]
# ##### 데이터를 새로 불러오자
#    - 실습으로 인해 원본 데이터가 지저분해졌다.. 다시 불러오자

# %%
# 데이터를 새로 불러오자
car = pd.read_excel('./실습데이터/car_mpg.xlsx')
del car['Unnamed: 0']

car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %% [markdown]
# #### 문제05]
#    - 구동방식별로 고속도로, 도시연비의 평균을 구해보고
#    - 이를 데이터 프레임으로 만들어서 막대바로 시각화 해보기

# %%
car[['hwy', 'cty']].apply(np.mean, axis=0).plot.bar()

# %% [markdown]
# ##### 문제06]
#  - 자동차(class) 중에서 어떤 자동차가 가장 많은지 알아보려고 한다.
#  - 종류별 빈도를 막대바로 시각화 해보자

# %%
car['class'].value_counts().plot.bar()

# %% [markdown]
# ##### 문제07]
#  - 어떤 회사에서 생산한 suv 차종의 도시 연비가 높은지 알아보려고 한다.
#  - suv 차종을 대상으로 평균 도시연비가 가장 높은 회사 다섯곳을 막대 바로 시각화 해보자.

# %%
suv_df = car[car['class'] == 'suv']
pivot_df = suv_df.pivot_table('cty', 'manufacturer', 'class', aggfunc='mean')

pivot_df.columns = ['suv_average_cty']
big5_suv = pivot_df.sort_values(by='suv_average_cty', ascending=False).iloc[0:5, :]

big5_suv.plot.bar()

# %% [markdown]
# ## 7. 이상치정제
#    - car_mpg 데이터에서 구동방식별 고속도로 연비 평균과 도시연비 평균을 이상치를 제외하고 확인
#    - 각 연비별 이상치확인 boxplot()

# %%
# 데이터를 새로 불러오자
data_df = pd.read_excel('./실습데이터/car_mpg.xlsx')
del data_df['Unnamed: 0']

data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
outlier_df = data_df.filter(['hwy', 'cty'])
outlier_df.boxplot()
plt.show()

# %% [markdown]
# ##### 3사분위 정보를 얻어본다면?

# %%
quantile75 = outlier_df.quantile(q=0.75)
quantile75
# Out:
# hwy    27.0
# cty    19.0
# Name: 0.75, dtype: float64

# %% [markdown]
# ##### 1사분위 정보를 얻어온다면?

# %%
quantile25 = outlier_df.quantile(q=0.25)
quantile25
# Out:
# hwy    18.0
# cty    14.0
# Name: 0.25, dtype: float64

# %% [markdown]
# ##### IQR (3사분위수 - 1사분위수)

# %%
IQR = quantile75 - quantile25
IQR
# Out:
# hwy    9.0
# cty    5.0
# dtype: float64

# %% [markdown]
# ##### 최저한계치와 최고한계치
#    - 최저한계치보다 작거나, 최고한계치보다 큰 경우 이상치로 간주한다.

# %%
# 최저 한계치(lower fence)
lower_fence = quantile25 - 1.5 * IQR
print('lower_fence :\n', lower_fence)

print()  ## 줄간격

# 최고 한계치(upper fence)
upper_fence = quantile75 + 1.5 * IQR
print('upper_fence :\n', upper_fence)
# Out:
# lower_fence :
#  hwy    4.5
# cty    6.5
# dtype: float64
#
# upper_fence :
#  hwy    40.5
# cty    26.5
# dtype: float64

# %% [markdown]
# ##### 극단치 경계 값을 얻어 보자(아래 수평선)

# %%
lower_outlier = outlier_df[outlier_df > lower_fence].apply(min)
lower_outlier
# Out:
# hwy    12
# cty     9
# dtype: int64

# %% [markdown]
# ##### 극단치 경계 값을 얻어 보자(위 수평선)

# %%
upper_outlier = outlier_df[outlier_df < upper_fence].apply(max)
upper_outlier
# Out:
# hwy    37.0
# cty    26.0
# dtype: float64

# %%
# 이상치를 결측값으로 변경
# 고속도로 연비의 이상치 데이터 추출
hwy_outlier_df = data_df.query("hwy >" + str(upper_outlier['hwy']))
hwy_outlier_df
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
# 도시연비의 이상치데이터 추출
cty_outlier_df = data_df.query("cty >" + str(upper_outlier['cty']))
cty_outlier_df
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 99         honda       civic    1.6  1999    4  manual(m5)   f   28   33  r
# 196       toyota     corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 99   subcompact
# 196     compact
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
# copy() : 원본은 그대로 두고 복사본에 이상치를 제거하자
outlier_clean_df = data_df.copy()
outlier_clean_df.head(10)
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4         audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5         audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6         audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7         audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# 8         audi  a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
#
#      class
# 0  compact
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact
# 6  compact
# 7  compact
# 8  compact
# 9  compact

# %%
# hwy 연비에 대한 이상치를 결측값으로 변경

outlier_clean_df.loc[hwy_outlier_df.index, 'hwy'] = np.NaN
outlier_clean_df.loc[cty_outlier_df.index, 'cty'] = np.NaN

outlier_clean_df[ ['hwy', 'cty'] ].boxplot()


# 이상치가 제거되었음을 볼 수 있다.

# %%
# 결측값을 제거한 구동방식별 고속도로, 도시연비 평균

drv_mean_df = outlier_clean_df.filter(['drv', 'hwy', 'cty']).dropna().groupby('drv').agg(np.mean)
drv_mean_df
# Out:
#            hwy        cty
# drv
# 4    19.174757  14.330097
# f    27.584158  19.445545
# r    21.000000  14.080000

# %%
# 시각화 
drv_mean_df.plot.bar(rot=0)
plt.grid()
plt.title('이상치 제거 후 고속도로연비와 도시연비 평균 비교')
plt.xlabel('구동방식')
plt.ylabel('평균')
plt.show()
